# %%
import json
import pandas as pd
import numpy as np
from math import *
import matplotlib.pyplot as plt
from ob import objects

pd.DataFrame(objects)
# Out:
#    Борщ   Щи  Молочный  Солянка  Грибной  Медовик  Наполеон  Сникерс  Ириска  \
# s -0.25 -0.2       0.3     -0.4     -0.1      0.7       0.8     0.90     1.0
# w  0.65  0.7       0.9      0.6      0.5      0.2       0.1     0.05    -0.1
#
#    Твикс
# s   0.85
# w   0.15

# %%
fig, ax = plt.subplots()
ax.set_xlabel(' Сладкость    ')
ax.set_ylabel(' Жидкость(состояние)    ')
x = [objects[i]['s'] for i in objects.keys()]
y = [objects[i]['w'] for i in objects.keys()]
ax.scatter(x,y)
fig.set_figwidth(6)
fig.set_figheight(4)
for i in objects.keys():
    plt.annotate('hello',xy=(0.5,0.5))
plt.show()
